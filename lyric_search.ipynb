# %%
import pandas as pd
import numpy as np
import nltk
import re

from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\tr21\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv("spotify_songs.csv")

df = df[['track_name', 'artist_name', 'lyrics']]
df.dropna(inplace=True)

df.head()
# Out:
#             track_name      artist_name  \
# 0  On Top of the World  Imagine Dragons
# 1         Shape of You       Ed Sheeran
# 2      Blinding Lights       The Weeknd
# 3     Someone Like You            Adele
# 4             Believer  Imagine Dragons
#
#                                               lyrics
# 0  I'm on top of the world hey waiting on this fo...
# 1  The club isn't the best place to find a lover ...
# 2  I said ooh I'm blinded by the lights no I can'...
# 3  Never mind I'll find someone like you I wish n...
# 4  First things first I'ma say all the words insi...

# %%
def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    tokens = text.split()
    tokens = [word for word in tokens if word not in stop_words]
    return " ".join(tokens)

df['cleaned_lyrics'] = df['lyrics'].apply(preprocess_text)

# %%
tfidf = TfidfVectorizer(max_features=5000)
lyrics_tfidf = tfidf.fit_transform(df['cleaned_lyrics'])

# %%
def predict_song(input_lyrics):
    input_lyrics = preprocess_text(input_lyrics)
    input_vector = tfidf.transform([input_lyrics])

    similarity_scores = cosine_similarity(input_vector, lyrics_tfidf)
    best_match_index = similarity_scores.argmax()

    song = df.iloc[best_match_index]['track_name']
    artist = df.iloc[best_match_index]['artist_name']

    return song, artist

# %%
test_lyrics = "I'm on top of the world tonight"
song, artist = predict_song(test_lyrics)

print("Predicted Song:", song)
print("Predicted Artist:", artist)
# Out:
# Predicted Song: On Top of the World
# Predicted Artist: Imagine Dragons
